# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os

def fetch_adjusted_prices(ticker, multiplier, timespan, start_date, end_date):
    """
    Fetch historical price data and adjust for reverse splits.

    Args:
        ticker (str): The ticker symbol.
        multiplier (int): The multiplier for the timespan.
        timespan (str): Aggregation period (e.g., 'day', 'hour').
        start_date (str): Start date in 'YYYY-MM-DD' format.
        end_date (str): End date in 'YYYY-MM-DD' format.

    Returns:
        pd.DataFrame: Adjusted historical price data.
    """
    load_dotenv()

    # Get API key from environment variables
    api_key = os.getenv("POLYGON_API_KEY")
    if not api_key:
        raise ValueError("API key not found. Ensure POLYGON_API_KEY is set in your .env file.")

    # Fetch historical price data
    url_prices = f"https://api.polygon.io/v2/aggs/ticker/{ticker}/range/{multiplier}/{timespan}/{start_date}/{end_date}"
    response_prices = requests.get(url_prices, params={"apiKey": api_key})

    if response_prices.status_code == 200:
        data_prices = response_prices.json()
        if "results" in data_prices:
            df = pd.DataFrame(data_prices["results"]).rename(columns={
                "t": "timestamp",
                "o": "open",
                "h": "high",
                "l": "low",
                "c": "close",
                "v": "volume",
            })
            df["date"] = pd.to_datetime(df["timestamp"], unit="ms").dt.date
            df = df[["date", "open", "high", "low", "close", "volume"]]
            df.set_index(pd.to_datetime(df["date"]), inplace=True)
            df.drop(columns=["date"], inplace=True)
        else:
            raise ValueError("No results found in the price response.")
    else:
        raise ConnectionError(f"Error fetching price data: {response_prices.status_code}, {response_prices.text}")

    # Fetch split data to adjust for reverse splits
    url_splits = "https://api.polygon.io/v3/reference/splits"
    response_splits = requests.get(url_splits, params={"ticker": ticker, "apiKey": api_key, "reverse_split": True})

    if response_splits.status_code == 200:
        data_splits = response_splits.json()
        if "results" in data_splits:
            splits = pd.DataFrame(data_splits["results"])
            splits["execution_date"] = pd.to_datetime(splits["execution_date"])
            splits.sort_values("execution_date", inplace=True)

            # Apply reverse split adjustments
            for _, split in splits.iterrows():
                split_date = split["execution_date"]
                split_ratio = split["split_from"] / split["split_to"]
                mask = df.index < split_date
                df.loc[mask, ["open", "high", "low", "close"]] *= split_ratio
                df.loc[mask, "volume"] /= split_ratio
        else:
            print("No split data found in the response.")
    else:
        raise ConnectionError(f"Error fetching split data: {response_splits.status_code}, {response_splits.text}")

    return df

# Example usage
if __name__ == "__main__":
    ticker = "VXX"
    multiplier = 1
    timespan = "day"
    start_date = "2017-01-01"
    end_date = "2024-12-23"

    try:
        vxx_history = fetch_adjusted_prices(ticker, multiplier, timespan, start_date, end_date)
        print(vxx_history)
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
#                open     high       low    close        volume
# date
# 2023-01-09  3409.92  3484.16  3379.200  3448.32  2.404977e+04
# 2023-01-10  3467.52  3468.80  3294.720  3304.96  2.320002e+04
# 2023-01-11  3281.92  3338.24  3279.360  3320.32  2.547651e+04
# 2023-01-12  3256.32  3302.40  3151.360  3156.48  4.177954e+04
# 2023-01-13  3179.52  3179.52  3048.960  3077.12  3.743063e+04
# ...             ...      ...       ...      ...           ...
# 2024-12-17    43.75    44.50    43.240    44.29  4.126272e+06
# 2024-12-18    44.00    51.89    43.380    51.72  8.144114e+06
# 2024-12-19    49.59    56.85    48.890    56.14  1.142816e+07
# 2024-12-20    55.82    55.98    47.625    48.08  1.097014e+07
# 2024-12-23    46.92    48.82    44.380    44.38  4.045915e+06
#
# [493 rows x 5 columns]

# %%
import pandas as pd
import requests
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

# Retrieve the API key from the .env file
api_key = os.getenv("IVOLATILITY_API_KEY")

symbol = "aA"
trade_date = "2024-12-23"
dteFrom = 7
dteTo = 30
deltaFrom = 0
deltaTo = 1
cp = "C"

# Construct the URL
url = "https://restapi.ivolatility.com/equities/eod/stock-opts-by-param"
params = {
    "apiKey": api_key,
    "symbol": symbol,
    "tradeDate": trade_date,
    "dteFrom": dteFrom,
    "dteTo": dteTo,
    "deltaFrom": deltaFrom,
    "deltaTo": deltaTo,
    "cp": cp
}

# Make the request
response = requests.get(url, params=params)

# Check the response
if response.status_code == 200:
    json_data = response.json()  # Parse JSON response
    data = json_data.get("data")  # Extract the 'data' key
    if data:  # Check if data exists
        df = pd.DataFrame(data)  # Convert to pandas DataFrame
        print(df)  # Display the DataFrame
    else:
        print("No data available:", json_data)
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# No data available: {'status': {'executionTime': 12, 'recordsFound': 1000000, 'code': 'PENDING', 'urlForDetails': 'https://restapi.ivolatility.com/data/info/86a8ce92-ac16-4a63-9ba5-e9ce2e7aea7a'}, 'query': {'requestUUID': '86a8ce92-ac16-4a63-9ba5-e9ce2e7aea7a'}, 'data': []}

# %%
import requests
import os
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime, timedelta
import time
import gzip
import shutil

# Load environment variables from .env file
load_dotenv()

# Retrieve the API key from the .env file
api_key = os.getenv("IVOLATILITY_API_KEY")

if not api_key:
    raise ValueError("API key is not set in the .env file or environment variables.")

# Define the API endpoint
url = "https://restapi.ivolatility.com/equities/eod/stock-opts-by-param"

def fetch_option_data(symbol, trade_date, dteFrom, dteTo, deltaFrom, deltaTo, cp):
    """Fetches option data (calls or puts) and returns a dataframe."""
    params = {
        "apiKey": api_key,
        "symbol": symbol,
        "tradeDate": trade_date,
        "dteFrom": dteFrom,
        "dteTo": dteTo,
        "deltaFrom": deltaFrom,
        "deltaTo": deltaTo,
        "cp": cp
    }

    try:
        # Initial API request
        response = requests.get(url, params=params)
        response.raise_for_status()

        # Parse the response
        data = response.json()

        # Handle direct data response
        if "data" in data and data["data"]:
            return pd.DataFrame(data["data"])
        
        # Handle pending data
        elif data.get("status", {}).get("code") == "PENDING":
            status_url = data["status"]["urlForDetails"]

            while True:
                # Poll for data availability
                status_response = requests.get(status_url)
                status_response.raise_for_status()
                status_data = status_response.json()

                # Check data availability
                if isinstance(status_data, list) and len(status_data) > 0:
                    meta = status_data[0].get("meta", {})
                    if meta.get("status") == "COMPLETE":
                        file_info = status_data[0].get("data", [])[0]
                        download_url = file_info.get("urlForDownload")

                        if download_url:
                            # Download and decompress the file
                            download_response = requests.get(download_url)
                            gz_filename = f"{symbol}_{cp}_{trade_date}.csv.gz"
                            with open(gz_filename, "wb") as f:
                                f.write(download_response.content)

                            # Check if the file is empty
                            with gzip.open(gz_filename, "rb") as gz_file:
                                content = gz_file.read()
                                if not content.strip():  # Empty file
                                    print(f"No data available in the downloaded file for {cp} on {trade_date}.")
                                    os.remove(gz_filename)
                                    return pd.DataFrame()

                            # Decompress and read into a dataframe
                            with gzip.open(gz_filename, "rb") as gz_file:
                                df = pd.read_csv(gz_file)
                            os.remove(gz_filename)  # Clean up temporary file
                            return df
                        else:
                            print(f"Download URL for {cp} on {trade_date} not found.")
                            break
                    elif meta.get("status") == "FAILED":
                        print(f"Data retrieval for {cp} on {trade_date} failed.")
                        break
                else:
                    print(f"Data for {cp} on {trade_date} still processing. Retrying in 10 seconds...")
                    time.sleep(10)

        else:
            raise ValueError(f"No data or status URL found for {cp} on {trade_date}.")

    except requests.exceptions.RequestException as e:
        print(f"An error occurred while fetching {cp} data on {trade_date}: {e}")

    return pd.DataFrame()  # Return an empty dataframe if data is unavailable

# Define query parameters
symbol = "SPY"
start_date = "2001-01-01"
# end_date = datetime.now().strftime("%Y-%m-%d")
end_date = "2011-01-01"
dteFrom = 0
dteTo = 600

# Output directory
output_dir = f"../historical/{symbol}/"
os.makedirs(output_dir, exist_ok=True)  # Create directory if it doesn't exist

# Iterate over date range in reverse
start_date_obj = datetime.strptime(start_date, "%Y-%m-%d")
end_date_obj = datetime.strptime(end_date, "%Y-%m-%d")
current_date = end_date_obj

while current_date >= start_date_obj:
    # Skip weekends
    if current_date.weekday() in [5, 6]:  # 5 = Saturday, 6 = Sunday
        current_date -= timedelta(days=1)
        continue

    trade_date = current_date.strftime("%Y-%m-%d")
    output_path = f"{output_dir}/{symbol}_daily_{trade_date}.csv"

    # Check if the file already exists
    if os.path.exists(output_path):
        print(f"File already exists for {trade_date}. Skipping...")
        current_date -= timedelta(days=1)
        continue

    # Fetch calls and puts data
    calls_df = fetch_option_data(symbol, trade_date, dteFrom, dteTo, deltaFrom=0, deltaTo=1, cp="C")
    puts_df = fetch_option_data(symbol, trade_date, dteFrom, dteTo, deltaFrom=-1, deltaTo=0, cp="P")

    # Concatenate the dataframes
    if not calls_df.empty or not puts_df.empty:
        combined_df = pd.concat([calls_df, puts_df], ignore_index=True)
        combined_df.to_csv(output_path, index=False)
        print(f"Combined data saved to '{output_path}'.")
    else:
        print(f"No data retrieved for {trade_date}.")

    # Move to the previous day
    current_date -= timedelta(days=1)

    time.sleep(.3)

print("Data fetching completed.")
# Out:
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-27.csv'.
# No data available in the downloaded file for C on 2010-12-24.
# No data available in the downloaded file for P on 2010-12-24.
# No data retrieved for 2010-12-24.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-12-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-26.csv'.
# No data available in the downloaded file for C on 2010-11-25.
# No data available in the downloaded file for P on 2010-11-25.
# No data retrieved for 2010-11-25.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-11-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-10-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-07.csv'.
# No data available in the downloaded file for C on 2010-09-06.
# No data available in the downloaded file for P on 2010-09-06.
# No data retrieved for 2010-09-06.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-09-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-08-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-06.csv'.
# No data available in the downloaded file for C on 2010-07-05.
# No data available in the downloaded file for P on 2010-07-05.
# No data retrieved for 2010-07-05.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-07-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-06-01.csv'.
# No data available in the downloaded file for C on 2010-05-31.
# No data available in the downloaded file for P on 2010-05-31.
# No data retrieved for 2010-05-31.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-05-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-05.csv'.
# No data available in the downloaded file for C on 2010-04-02.
# No data available in the downloaded file for P on 2010-04-02.
# No data retrieved for 2010-04-02.
# Combined data saved to '../historical/SPY//SPY_daily_2010-04-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-03-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-16.csv'.
# No data available in the downloaded file for C on 2010-02-15.
# No data available in the downloaded file for P on 2010-02-15.
# No data retrieved for 2010-02-15.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-02-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-19.csv'.
# No data available in the downloaded file for C on 2010-01-18.
# No data available in the downloaded file for P on 2010-01-18.
# No data retrieved for 2010-01-18.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2010-01-04.csv'.
# No data available in the downloaded file for C on 2010-01-01.
# No data available in the downloaded file for P on 2010-01-01.
# No data retrieved for 2010-01-01.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-28.csv'.
# No data available in the downloaded file for C on 2009-12-25.
# No data available in the downloaded file for P on 2009-12-25.
# No data retrieved for 2009-12-25.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-12-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-27.csv'.
# No data available in the downloaded file for C on 2009-11-26.
# No data available in the downloaded file for P on 2009-11-26.
# No data retrieved for 2009-11-26.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-11-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-10-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-08.csv'.
# No data available in the downloaded file for C on 2009-09-07.
# No data available in the downloaded file for P on 2009-09-07.
# No data retrieved for 2009-09-07.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-09-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-08-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-06.csv'.
# No data available in the downloaded file for C on 2009-07-03.
# No data available in the downloaded file for P on 2009-07-03.
# No data retrieved for 2009-07-03.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-07-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-06-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-26.csv'.
# No data available in the downloaded file for C on 2009-05-25.
# No data available in the downloaded file for P on 2009-05-25.
# No data retrieved for 2009-05-25.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-05-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-13.csv'.
# No data available in the downloaded file for C on 2009-04-10.
# No data available in the downloaded file for P on 2009-04-10.
# No data retrieved for 2009-04-10.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-04-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-03-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-17.csv'.
# No data available in the downloaded file for C on 2009-02-16.
# No data available in the downloaded file for P on 2009-02-16.
# No data retrieved for 2009-02-16.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-02-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-20.csv'.
# No data available in the downloaded file for C on 2009-01-19.
# No data available in the downloaded file for P on 2009-01-19.
# No data retrieved for 2009-01-19.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2009-01-02.csv'.
# No data available in the downloaded file for C on 2009-01-01.
# No data available in the downloaded file for P on 2009-01-01.
# No data retrieved for 2009-01-01.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-26.csv'.
# No data available in the downloaded file for C on 2008-12-25.
# No data available in the downloaded file for P on 2008-12-25.
# No data retrieved for 2008-12-25.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-12-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-28.csv'.
# No data available in the downloaded file for C on 2008-11-27.
# No data available in the downloaded file for P on 2008-11-27.
# No data retrieved for 2008-11-27.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-11-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-02.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-10-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-17.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-16.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-10.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-09.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-03.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-09-02.csv'.
# No data available in the downloaded file for C on 2008-09-01.
# No data available in the downloaded file for P on 2008-09-01.
# No data retrieved for 2008-09-01.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-27.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-26.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-20.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-19.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-15.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-14.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-13.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-12.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-11.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-08.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-07.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-06.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-05.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-04.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-08-01.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-31.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-30.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-29.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-28.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-25.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-24.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-23.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-22.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-21.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-18.csv'.
# Combined data saved to '../historical/SPY//SPY_daily_2008-07-17.csv'.
